#   inflating: content/cvpr2016_flowers/images/image_00475.jpg
#   inflating: content/cvpr2016_flowers/images/image_06584.jpg
#   inflating: content/cvpr2016_flowers/images/image_01094.jpg
#   inflating: content/cvpr2016_flowers/images/image_02680.jpg
#   inflating: content/cvpr2016_flowers/images/image_04894.jpg
#   inflating: content/cvpr2016_flowers/images/image_02417.jpg
#   inflating: content/cvpr2016_flowers/images/image_00554.jpg
#   inflating: content/cvpr2016_flowers/images/image_04562.jpg
#   inflating: content/cvpr2016_flowers/images/image_08048.jpg
#   inflating: content/cvpr2016_flowers/images/image_06396.jpg
#   inflating: content/cvpr2016_flowers/images/image_07544.jpg
#   inflating: content/cvpr2016_flowers/images/image_04753.jpg
#   inflating: content/cvpr2016_flowers/images/image_04125.jpg
#   inflating: content/cvpr2016_flowers/images/image_05777.jpg
#   inflating: content/cvpr2016_flowers/images/image_07768.jpg
#   inflating: content/cvpr2016_flowers/images/image_06554.jpg
#   inflating: content/cvpr2016_flowers/images/image_02048.jpg
#   inflating: content/cvpr2016_flowers/images/image_07889.jpg
#   inflating: content/cvpr2016_flowers/images/image_06327.jpg
#   inflating: content/cvpr2016_flowers/images/image_05835.jpg
#   inflating: content/cvpr2016_flowers/images/image_05299.jpg
#   inflating: content/cvpr2016_flowers/images/image_05900.jpg
#   inflating: content/cvpr2016_flowers/images/image_02737.jpg
#    creating: content/cvpr2016_flowers/.ipynb_checkpoints/

# %%
# Load captions
import os

def load_captions(captions_folder, image_folder):
    captions = {}
    image_files = os.listdir(image_folder)

    for image_file in image_files:
        image_name = image_file.split(".")[0]
        caption_file = os.path.join(captions_folder, image_name + ".txt")
        with open(caption_file, "r") as f:
            caption = f.readlines()[0].strip()
        if image_name not in captions:
            captions[image_name] = caption
    return captions

captions_folder = "./content/cvpr2016_flowers/captions"
image_folder = "./content/cvpr2016_flowers/images"
captions = load_captions(captions_folder, image_folder)
captions
# Out:
# {'image_05772': 'this flower has a large centr with spiky petals that are grey on the outside and red on the inside. the stamen is white',
#  'image_05295': 'the petals are a stark white with numerous yellow stamen at center.',
#  'image_00194': 'the flower has white stringy petals with yellow and purple pollen tubes',
#  'image_03182': 'the anthers are in the center, with yellow and orange petals that are perforated on the borders.',
#  'image_02020': 'this flower has a broad pink and white petal with a protruding, thick white and pink pistil.',
#  'image_01589': 'this flower has petals that are purple with white steman',
#  'image_02728': 'this flower is many small flower heads clustered in a ball shape and the colour is a deep orange.',
#  'image_08050': 'this flower has petals that are pink with many layers',
#  'image_07717': 'this flower is pink in color, with petals that darker veins.',
#  'image_01620': 'the petals on this flower are white with pink striples.',
#  'image_03739': 'this flower is pink in color, with petals that are curled and wavy.',
#  'image_05211': 'this is a large,orange flower with red and yellow stamen.',
#  'image_01291': 'this flower is pink in color, with petals that are closely wrapped around the center.',
#  'image_01052': 'the flower has small yellow and orange petals with white anther',
#  'image_06065': 'a purple flower with tiny petals and a huge green pedicel.',
#  'image_06091': 'this flower is pink and green in color, with petals that are spikey.',
#  'image_07191': 'this flower is pink and purple in color, with petals that are spotted.',
#  'image_05587': 'the petals of the flowers are various shades of pink and have five individual petals.',
#  'image_01104': 'this flower is orange and white in color, with petals that have dark veins.',
#  'image_06629': 'sepals rae green in clor,flowew is purple in color witha prominent pistil',
#  'image_04050': 'the flower has small yellow petals that are dense and thin.',
#  'image_00537': 'the purple petals curve upwards and come to a point. they are darker at the bottom.',
#  'image_07072': 'these dark purple flowers have thick yellow stamen and curved petals.',
#  'image_03513': 'the edges of the flower are white while the inside is purple and the leaves are green.',
#  'image_05573': 'this flower is pink and purple in color, with petals that are oval shaped.',
#  'image_06920': 'a feather like, pink petaled flower with a full green stem.',
#  'image_02094': 'the petals are pure white and broad, while the stamen is pointing out and white.',
#  'image_07478': 'the flowers has petals that are white with a white stigma.',
#  'image_00097': 'this weird flower has a dense arrangement of blue-white petals and an ornate pistil-stamen arrangement.',
#  'image_07344': 'large flower with many vase like tubes which are purple in color and white spots in the inside of vase.',
#  'image_07304': 'this flower is white and black in color, with petals that are spotted on the inside.',
#  'image_03812': 'this flower has petals that are pale pink, with pink filaments and gray anthers.',
#  'image_04303': 'this flower has large pink petals and yellow spots white no visible outer stamen',
#  'image_05851': 'this flower has thin bright yellow petals with a dark brown stamen.',
#  'image_00126': 'this flower has protuberant green stamen with large anthers surrounded by a circular purple fringe and a bottom layer of wide tapered purple petals.',
#  'image_05180': 'this is a flower with orange petals and a brown pistil.',
#  'image_00284': 'this flower has a long white petal and a lot of yellow stigma in the middle',
#  'image_07162': 'this flower has five large orange petals with dark spots on them and also long protruding stamen.',
#  'image_01856': 'this flower is white and pink in color, with petals that are point at the tip.',
#  'image_00846': 'the flower has a smooth white petal with yellow in the center',
#  'image_04531': 'the flower has narrow yellow and red petals with red anthers.',
#  'image_01153': 'this flower has bright orange petals as its main feature',
#  'image_03080': 'this petals on this flower are purple with tiny white tips.',
#  'image_05523': 'this purple flower features many narrow purple petals with crinkles surrounding a purple stigma and many yellow stamen.',
#  'image_05544': 'this bright purple flower has long, pointed but slightly rounded petals and yellow stamen surrounding a purple stigma.',
#  'image_03963': 'purple petals that are almost heart shaped with small green receptacles.',
#  'image_01803': 'this flower has a protruding yellow pollen tube surrounded by five large, rounded red petals.',
#  'image_05882': 'the petals are long and bright yellow and the center of the flower is black.',
#  'image_03797': 'this flower has long purple stamen surrounded by several long, very thin purple petals which curve slightly backwards.',
#  'image_07936': 'this flower has the row of red petals shaded with yellow color at the end holding the red stamens with the anthers at the center',
#  'image_06136': 'this flower has petals that are white with a patch of yellow',
#  'image_04584': 'this flower is pink and white in color, and has petals that are wavy and close together.',
#  'image_00415': 'the flower petals are alternating and are wihte in color with yellow stamen',
#  'image_04162': 'this flower is white, purple and yellow in color, with petals that are striped.',
#  'image_04018': 'the flower shown has yellow petals surrounding yellow stamen',
#  'image_04413': 'the petals of this flower are red with a long stigma',
#  'image_00496': 'pedicel is green,petals are broader and are beige in color',
#  'image_06938': 'this flower is yellow and purple in color, with petals that are ruffled at the edges.',
#  'image_03796': 'this flower is pink in color, and has petals that are wavy and skinny',
#  'image_01734': 'the petals on this flower are big with ruffles on the edges and a filament with budding anthers',
#  'image_03096': 'this flower has petals that are [ink with patches of yellow',
#  'image_06458': 'this flower has petals that are purple with green stamn',
#  'image_00042': 'the flower shown has stringy purple petals which are its dominant feature',
#  'image_00745': 'the petals on this flower are yellow with yellow stamen in the center',
#  'image_06662': 'this flower has small, bright yellow petals - the outer layer lies flat and the inner petals curl over to conceal the center of the flower.',
#  'image_02002': 'the flower has a long yellow pollen tube and a red shiny petal.',
#  'image_04958': 'this rounded flower consists of a cluster of bright yellow, trumpet-shaped petals, and has oblong leaves of dark green.',
#  'image_06584': 'this flower is bright purple with many pedals that are roundish whth pale white outer petals',
#  'image_05202': 'this flower has orange narrow petals and tiny yellow stamen.',
#  'image_07633': 'the flower is arranged in three layers and is light pink in color.',
#  'image_02375': 'the large, delicate purple and lavender blossoms grow from a single long stem.',
#  'image_03560': 'a flower with purple petals and lavender anther filaments.',
#  'image_05575': 'this flower has petals that are pink with yellow stamen',
#  'image_03310': 'this unique flower has several orange spikey petals with a bright blue stigma.',
#  'image_07917': 'this brightly colored flower has a single row of petals, orange at the center and yellow on the outer edges, radiating from a central core of burgundy and yellow anthers.',
#  'image_04630': 'this flower is yellow in color, with petals that are rounded on the ends.',
#  'image_05641': 'this is a small flower with pink and white petals and a green pedicel.',
#  'image_03357': "the flower has a very thick set of orange petals with it's inner parts a light yellow color.",
#  'image_00347': 'that flower has nice white petals and cool green leaves that allow it to float on the water.',
#  'image_03266': 'the flower has several yellow colored petals with the middle in an orange hue.',
#  'image_02035': 'the petals in this flower make it look like a heart',
#  'image_02941': 'what a beautiful flower. i love the light pink and orange small pedals that surround the stigma which is yellow.',
#  'image_03325': 'this flower has long and pointy yellow petals with no visible outer stigma',
#  'image_04385': 'light purple petals and dark purple ovary',
#  'image_01095': 'these lovely yellow petaled-flowers have intricate, lighter innards.',
#  'image_04847': 'the pedicel has a single flower which is red and white.',
#  'image_00236': 'this flower has petals that are white with purple stingy stamens',
#  'image_07780': 'this flower has petals that are purple with purple stamen',
#  'image_01437': 'this flower has a white petal and a white colored stamen',
#  'image_01050': 'this flower is orange in color, with petals that are wavy and curled.',
#  'image_02172': 'this flower has one large flat white peddle that goes all the way around.',
#  'image_06937': 'this is a purple flower with a yellow pollen center,',
#  'image_00319': 'the flower shown has white petals, and bright yellow anthers.',
#  'image_01278': 'this is a yellow rose with orange on the petals and leaves.',
#  'image_06404': 'a purple flower with heart shaped petals and tiny white anther.',
#  'image_07931': 'a group of red flowers with yellow tipped petals accompanied by maroon anther filaments.',
#  'image_00614': 'the petals of this flower are orange with a long stigma',
#  'image_03892': 'this flower has an orange stigma with pink petals that drop downward.',
#  'image_01823': 'this petty flower has large petals that fade from light pink to dark pink.',
#  'image_02573': 'a group of flowers with white petals and yellow pistils in the center.',
#  'image_00100': 'the pistil area of this flower appears similar to a venus fly trap in design.',
#  'image_05469': 'this white flower has long slender petals around a small green and yellow pollen tube.',
#  'image_04062': 'this flower has petals that are yellow and are stringy',
#  'image_01226': 'this flower has petals that are overlapping and light pink.',
#  'image_01257': 'this flower is red in color, with petals that are closely wrapped around the center.',
#  'image_05053': 'this flower is orange and yellow in color, with petals that are oval shaped.',
#  'image_00853': 'this flower has petals that are yellow with white tips',
#  'image_07286': 'the flowers have skinny pink petals with pink filaments and dark pink anthers.',
#  'image_04623': 'this flower has petals that are pink with green patches',
#  'image_05007': 'this flower is yellow in color, with petals that are curled and bunched together.',
#  'image_07392': 'the flower has petals that are bright pink and bell shaped.',
#  'image_06406': 'the petals on this flower are purple and triangle shape.',
#  'image_08065': 'this flower has numerous layers of overlapping ruffled petals in yellow with pink edges.',
#  'image_06854': 'a flower with orange petals but no pistils or anther filaments in sight.',
#  'image_04025': 'a small flower with string like yellow petals surrounding yellow stigma.',
#  'image_07454': 'this flower has petals that are pink with white dots',
#  'image_06777': 'this flower has bright orange upturned petals with yellow streaks towards the center and extended large stamen.',
#  'image_01419': 'the flower shown has white petals with green sepal and pedicel',
#  'image_02630': 'this flower is yellow and pink in color, with petals that are rounded.',
#  'image_01922': 'a big flower that has white petals with pink tips, yellow big and stubby stigma, and thin yellow stamens.',
#  'image_07899': 'the flower shown has an outer ring of yellow while the lower petals are red',
#  'image_06785': 'the flower has a green pedicel as well as yellow sepals',
#  'image_00915': 'this flower is white and yellow in color, with petals that are multi colored and oval shaped.',
#  'image_04481': 'this flower has about twenty somewhat oval petals and each petal is a bright orange with a reddish streak down the middle of each petal.',
#  'image_04571': 'the bowl shaped pink flower has petals that are soft, smooth, thin and separately arranged around the stamen bunch',
#  'image_02612': 'a largish purple flower with five petals behind, and five petals in front.',
#  'image_00030': 'white petals on the outside purple white blue pedals inside purple yellow and white middle dark green leaves',
#  'image_01053': 'this flower has petals that are orange with yellow shading',
#  'image_06199': 'this flower has a lot of yellow stamen and numerous skinny and long white petals.',
#  'image_00031': 'this flower has long thin petals that are black at the base, white at the center, and blue at the tips.',
#  'image_04637': 'this flower is yellow in color, and has petals that are drooping downward.',
#  'image_00322': 'very pointy and is the color purple with yellow inside.',
#  'image_07466': 'the petals on this flower are pink with a short stigma',
#  'image_05158': 'the funnel shaped orange flower has petals that are soft, smooth and separately arranged around sepals',
#  'image_04282': 'the petals of the flowers are pink in color with light yellow patches and specks of black details.',
#  'image_00961': 'the yellow flower has petals that are soft, smooth and separately arranged around the bunch of stamen',
#  'image_05885': 'yellow petals, shaped like stalks of grass surround a darkish brown (maybe black) pistil.',
#  'image_03281': 'this flower is yellow in color, with petals that are ruffled at the edges.',
#  'image_03082': 'the flower shown has red petals in the shape of peppers and green stamen',
#  'image_07553': 'this flower is white in color, with petals that are very small.',
#  'image_03881': 'a flower with light purple petals accompanied by red pistils and anther filaments.',
#  'image_04274': 'this flower has petals that are white with red anthers.',
#  'image_07685': 'the petals on this flower are pink with brown stamen.',
#  'image_01270': 'the flower has a long green pedicel and overlapping red petals.',
#  'image_07405': 'this flower has petals that are pink with purple dots',
#  'image_01521': "this flower's pink petals with white edges ate veined and leaf like in appearance.",
#  'image_02508': 'this dark purple flower has a a round wide bell shape, there is no gap in the petals even at the end, the center is white with a small pistil.',
#  'image_06479': 'stamens are many with larger green anthers ,petals are light blue in color',
#  'image_08111': 'the flower has long stamen that are pink with pink petals.',
#  'image_05558': 'this round flower has many long, rounded petals in shades of pale purple.',
#  'image_01878': 'a prominent pistil with a larger stgma,yellow stamn',
#  'image_00964': 'this flower is yellow and red in color, with petals that are ruffled and rounded.',
#  'image_06638': 'a flower with a single conical purple petal and long green stigma',
#  'image_06724': 'the petals of this flower are white and purple with a long stigma',
#  'image_04508': 'this flower has pointy petals that are yellow and orange in the center.',
#  'image_06450': 'this flower had many purplish-blue flat pointed petals with light green stamen and thin pointy leaves.',
#  'image_06910': 'pretty pink petals with white jagged edges at the ends and a fairly long pedicel that is dark green.',
#  'image_00467': 'a purple flower with long, skinny petals that extend to a center that is on the bottom of the flower.',
#  'image_03451': 'this pretty little flower has red petals the drape down.',
#  'image_07618': 'this flower has petals that are pink with yellow stamen',
#  'image_02006': 'the prominent white pistil of this flower complements the large single red and green petal.',
#  'image_02932': 'this flower is yellow and peach in color, with petals that are oval shaped.',
#  'image_04329': 'this flower is pink and white in color, with petals that are ruffled at the edges.',
#  'image_02232': 'a flower that has a very feint pink tone on the petals, with a tan center',
#  'image_05593': 'this flower is pink in color, with petals that are wavy.',
#  'image_04266': 'this is a white flower with red markings and water droplets on the petals, and yellowish-green leaves.',
#  'image_04946': 'this white flower has a single white petal which is long and pointed and wraps around a yellow pistil.',
#  'image_04698': 'lavender petals on this flower with jagged green sepals.',
#  'image_03522': 'the inner portion of the petals is purplish red, while the outer portion is white.',
#  'image_04815': 'this flower has petals that are pink with red tips',
#  'image_07581': 'this blossom has a flowered white pollen tube surrounded by three pointed, leaflike pink petals.',
#  'image_01933': 'this is a semi-double white flower with pink tips on the petals.',
#  'image_01251': 'the petals of the flower are pink and yellow and layered in shape.',
#  'image_06368': 'this flower has petals that are yellow with dark lines',
#  'image_01849': 'this flower has petals that are pink with many layers',
#  'image_03889': 'pink thin petals surrounding a green stamen with orange anthers.',
#  'image_02371': 'the flower has folded red petals that are curved and round shaped.',
#  'image_07434': 'this flower has petals that are pink with purple dots',
#  'image_06374': 'this yellow flower has sparse long petals and yellow stamens.',
#  'image_00039': 'this flower is red and white in color, with petals that are oval shaped.',
#  'image_03273': 'the pretty little flower has four small yellow petals around its yellow center.',
#  'image_00013': 'lower petals are white in color,and larger in size,inner petals are purple in clor',
#  'image_02155': 'this is a round white flower with a long white stigma.',
#  'image_04092': 'this flower has spiky brown sepals topped by a hairlike purple fringe.',
#  'image_03415': 'this flower has purple petals and a green pedicel and is slumped over',
#  'image_04214': 'this flower has petals that are purple with yellow centers and white stamen.',
#  'image_03598': 'the petals are large and white and very delicate with red spots near the middle while the pollen tube is green and the stigma is bright red.',
#  'image_06641': 'the flower shown has purple petals as its main feature shaped like bells',
#  'image_03912': 'this is a flower with pink downward facing petals and a red center',
#  'image_02028': 'the petals of this flower are pink with a long stigma',
#  'image_01841': 'this flower is white and pink in color, with petals that are pink near the tips.',
#  'image_04853': 'this flower has petals that are pink with a white stripe and pink stamen.',
#  'image_04639': 'this flower is yellow in color, with petals that are rounded.',
#  'image_05244': 'this is a bell shaped flower with pedals of blue and yellow.',
#  'image_02599': 'this flower has many yellow stamen surrounded by five round pale pink petals and give pointed petals in a much darker pink.',
#  'image_00295': 'this flower has deep pink and light pink petals with yellow stamen center.',
#  'image_06054': 'the visible petals on the plant are thin and purple while the stem has spikes on it',
#  'image_05542': 'leaves are green,the petals ae pink and the anthers are yellow in color',
#  'image_07732': 'this flower is brown in color, with petals that have veins.',
#  'image_02554': 'this flower has five petals in back, and five white petals with pink centers, in front.',
#  'image_06476': 'this flower has purple petals and green pistil as its main features',
#  'image_04798': 'this flower has petals that are red with yellow stamen',
#  'image_06626': 'purple bell shaped flower with straight white stamen.',
#  'image_02198': 'a large dark pink flower with a large number of petals, and a round center.',
#  'image_02642': 'dark red petals darker red middle green and dark green',
#  'image_06646': 'this flower is pink in color, with petals that are bell shaped.',
#  'image_04760': 'the petals are delicate and light purple in color with rounded ends and the stamen is white.',
#  'image_05947': 'the petals are dark purple, with light purple towards the middle of the flower.',
#  'image_05864': 'the gorgeous flower has bright yellow petals with a dark receptacle.',
#  'image_07464': 'this flower is purple and white in color, with petals that are spotted on the inside.',
#  'image_06643': 'this flower has petals that are purple and in a bell shape',
#  'image_08136': 'this flower has small white petals and white pistil as its main features',
#  'image_00140': 'the flower has white petals and a purple pistil with purple bristles.',
#  'image_04280': 'this flower is pink in color, with petals that are striped near the center.',
#  'image_06009': 'petals are white in color,stamens are ,many and are yellow in color',
#  'image_01981': 'this flower has a large red spade shaped petal with a large yellow stamen with little bumps all over it.',
#  'image_00158': 'the flower shown has green sepal and purple pollen tubes',
#  'image_03033': 'long, thin, protruding pistil of powder purple color with matching wrinkled petals .',
#  'image_02565': 'there are two distinct sets of petals. the bottom layer is a darker shade of pink, while the upper layer consists of a light pink. there are 5 rows of petals on both rows.',
#  'image_03608': 'this flower has petals that are pink with pink stamen',
#  'image_04717': 'this flower has petals that are purple with yellow stigma',
#  'image_07636': 'this bright pink flower has yellow pistils and anther filaments.',
#  'image_02072': 'this flower is circular with white petals and white stamen.',
#  'image_07640': 'fat and wide pink flower with a yellow center.',
#  'image_00529': 'red, round petals are folded close over the center of these delicate flowers that point upward from thin, violet stems.',
#  'image_07422': 'a bell shaped flower with purple spotted petals and no visible pistils.',
#  'image_04823': 'the flower is capsule shaped with shorters stamen and pistil, with star shaped petals',
#  'image_01131': 'this flower is orange in color, with petals that has darker veins.',
#  'image_08106': 'the flower is big and has petals that are soft, smooth, curled and has dark red spots in them',
#  'image_05736': 'this flower has petals that are yellow and is bellow shaped',
#  'image_01667': 'this flower has petals that are purple with white stamen',
#  'image_01387': 'these white flower petals have pale yellow stamen inside of them.',
#  'image_01203': 'this flower has a pink petal and the petals are curved inwards and has no visible stamen',
#  'image_05929': 'this flower has petals that are purple with ruffled edges',
#  'image_06667': 'this flower is yellow in color, with petals that are curled inward.',
#  'image_05957': 'this flower has broad, white, round petals and yellow stamen with a green ovary.',
#  'image_07135': 'this flower has purple petals and two yellow anthers in the middle',
#  'image_07108': 'the petals on this flower are very delicate and purple in color.',
#  'image_00164': 'this flower has petals that are lavender, with purple filaments and green anthers.',
#  'image_05810': 'this flower is white and pink in color, with petals that are pink near the center.',
#  'image_05798': 'this flower is red and black in color, with petals that are pointed at the tips.',
#  'image_03391': 'pedicel are green in color,petals are brown spoted in color',
#  'image_08115': 'a flower with one large purple leaf behind a smaller set of 3 purple leaves.',
#  'image_02486': 'this flower is whit and blue in color, with petals that are all connected.',
#  'image_05501': 'the petals are both vertical and horizontal. they have a white color, with dark pink accents on the inside edge. they are also growing on branches which are brown.',
#  'image_07005': 'this flower has petals that are white and very prickly looking',
#  'image_07426': 'this flower has petals that are pink with purple dots',
#  'image_01047': 'this is a small flower with orange petals, and white styles.',
#  'image_04079': 'the yellow petals look like sticks with small yellow round stamen in the middle.',
#  'image_04505': 'this flower has a long yellow petal with a brown stripe and a yellow anther',
#  'image_02154': 'the pedals of this flower are white with a long stigma',
#  'image_04861': 'this flower is white and pink in color, with petals that are curved inward.',
#  'image_06570': 'a flower with small thin yellow petals and bright yellow stamen.',
#  'image_00289': 'this flower is pink and white in color, with petals that are multi colored.',
#  'image_00510': 'this flower has several delicately folded white petals with smooth edges and pink accents.',
#  'image_08153': 'the petals of this flower are white with a short stigma',
#  'image_04907': 'this flower has a thick white pistil surrounded by a pointed white petal with a pale pink center.',
#  'image_02676': 'this flower is pink in color, with petals that are rounded.',
#  'image_07705': 'the style is long and holds anthers on the sides.',
#  'image_02356': 'the petals are broad but thin at the edges, with purple tints at the edges and white in the middle.',
#  'image_04559': 'this flower is white and pink in color, with petals that are spotted.',
#  'image_01114': 'this flower has petals that are orange with white stamen',
#  'image_05468': 'this flower has petals that are pink white white shading',
#  'image_02482': 'this flower has petals that are blue with purple lines',
#  'image_07601': 'the flower has petals that are overlapping and red with yellow stamen.',
#  'image_00729': 'this flower has five large, rounded pink petals which are veined and slightly ruffled at the edges.',
#  'image_04419': 'the pedicel appears to be purple in color and the sepals are red in color.',
#  'image_05075': 'this flower is red and yellow in color, and has petals that are stacked on top of each other.',
#  'image_05961': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_06228': 'this flower has small white petals with yellow pistil as its main features',
#  'image_07057': 'the petals on this flower are white with yellow stamen.',
#  'image_03682': 'the petals of this flower are pink with a short stigma',
#  'image_05510': 'this flower has large white petals with a pink color in the center and grows on a tree.',
#  'image_07279': 'this flower is pink and yellow in color, and has petals that are rounded.',
#  'image_06616': 'the pink flower has bell shaped petal that is soft, smooth and enclosing stamen sticking out from the centre',
#  'image_07199': 'flower has long narrow orange spotted petals and a long thick pistill that is lighter in color.',
#  'image_05458': 'this beautiful flower has vibrant yellow petals and a large, brown core.',
#  'image_01078': 'this is a small yellow flower with a white stigma.',
#  'image_07876': 'this blossom is composed mainly of pink colored sepals, with no obvious petals.',
#  'image_00799': 'this flower is yellow and white in color, with petals that are oval shaped.',
#  'image_02287': 'this flower has long red petals and long white stamen in the center of it',
#  'image_03259': 'pedicel is green,petals are rounded and are white in color',
#  'image_01745': 'this flower has petals that are red with a big stigma',
#  'image_03126': 'this delicate pink flower has petals that drape over one another and cover the pistil and stamen under the petals.',
#  'image_01877': 'the flower has petals that are pink and separately arranged in layers around the pedicel',
#  'image_07988': 'the flower shown has orange petals and orange pistil in the center',
#  'image_04157': 'this flower is blue and green in color, with petals that are pointed on the ends.',
#  'image_05222': 'the royal blue star-shaped flower, with white tips, has fused petals and five streaks of green, framing the white pistil.',
#  'image_05543': 'this flower is pink in color, and has petals that are skinny and striped.',
#  'image_05320': 'this flower has petals that are white with yellow stamen',
#  'image_06701': 'this flower is white and purple in color, with petals that are spotted.',
#  'image_00303': 'this flower has petals that are pink with many layers and yellow steman',
#  'image_05282': 'the flower shown has white petals with yellow anther in the center',
#  'image_03124': 'this flower is white and pink in color, and has petals that are wavy and rounded.',
#  'image_01133': 'this flower has veined and overlapping orange petals with rounded edges.',
#  'image_08129': 'the petals on this flower are pink with long stamen.',
#  'image_02434': 'this flower has petals that are white with pink edges',
#  'image_05108': 'this flower has 4 leaves, three are purple and yellow with lines and one is solid purple.',
#  'image_01720': 'this flower is pink in color, with petals that are darker near the center.',
#  'image_02916': 'the petals on this flower are pink with pink veins.',
#  'image_04399': 'this flower is purple and orange in color, with petals that are wavy and uneven.',
#  'image_06657': 'this flower is yellow in color, with petals that are curled around the center.',
#  'image_02243': 'a flower with thin pink and white petals and cluster of white and yellow stamen',
#  'image_01552': 'this flower has petals that are red with short stamens',
#  'image_02975': 'this flower has petals that are orange with hints of yellow',
#  'image_01281': 'this flower is red in color, with petals that are curled on the edges.',
#  'image_03467': 'this flower is pink and white in color, with petals that are ruffled along the edges.',
#  'image_07991': 'the flower has rounded petals that are pink in color with shorter stamens',
#  'image_05802': 'many stamens with larger anthers that are pink in color',
#  'image_01929': 'long oval white petals with delicate lavender edges surround a plug-like yellow pistil with small stamen.',
#  'image_02467': 'this flower has petals that are blue with purple lines',
#  'image_02446': 'the funnel shaped flower is blue and has petal that is fused together',
#  'image_02435': 'the flower has whole purple petal and petals that are yellow and purple.',
#  'image_07505': 'bright orange petals white flowered middle light green leaves',
#  'image_00585': 'this flower has petals that are pink and closed together',
#  'image_05186': 'the bright golden petals are teardrop shaped, and encircle the many stamen in several layers.',
#  'image_01687': 'this flower has purple stamen surrounded by long, large white petals with pointed and ruffled edges.',
#  'image_07459': 'this flower has petals that are white with black dots',
#  'image_03386': 'this flower has long red petals that have white dots on it',
#  'image_02183': 'this flower has thick white petals as its main feature.',
#  'image_07320': 'a tall purple flower with multiple purple petals with dark spots.',
#  'image_06025': 'this flower has petals that are pink and folded together',
#  'image_05131': 'this flower has petals that are pink with purple and yellow lines',
#  'image_07335': 'the flowers have large green sepals and dotted purple petals.',
#  'image_02571': 'this flower is pink and white in color, with petals that are oval shaped.',
#  'image_07513': 'this flower has smooth purple petals and white pollen tubes as its main features',
#  'image_07831': 'this flower is purple in color, with petals that are ruffled and wavy.',
#  'image_07768': 'this flower is purple in color, with petals that are ruffled and wavy.',
#  'image_06764': 'a flower with large individual ribbed purple and white petals and large yellow individual stamen.',
#  'image_06457': 'this flower is purple in color, with petals that are layered.',
#  'image_06420': 'this flower is blue in color, with petals that are curled inward.',
#  'image_02005': 'this flower has a single, pink petal with a single pink stamen.',
#  'image_03215': 'this flower has thick yellow petals as its main feature.',
#  'image_06076': 'this flower has petals that are purple and very stringy',
#  'image_04911': 'this flower has a single white petal and white stamen.',
#  'image_06478': 'this flower has petals that are blue with green stamen',
#  'image_07827': 'this flower has petals that are purple ruffled around the edges',
#  'image_04902': 'this flower has a single white petal with pale orange stamen.',
#  'image_04124': 'this flower has petals that are purple and very stringy',
#  'image_07880': "the flowers has a strange looking red petals that looks very similar to it's leaves.",
#  'image_04546': 'this flower is yellow and red in color, with petals that are striped in the center.',
#  'image_02494': 'the petals are round and are pink in color with white details and have green details.',
#  'image_03537': 'the petals of this flower are purple with a white fringe.',
#  'image_07228': 'a multiple white pedaled flower with a yellow stigma.',
#  'image_05609': 'the flower shown has small pink petals with white pedicel',
#  'image_00723': 'this flower has petals that are yellow with a yellow stamen',
#  'image_07193': 'pale, black spotted pink petals curl away from long pistils and stamens in this downward facing blossom.',
#  'image_03653': 'this flower is red and yellow in color, with petals that are yellow near the center.',
#  'image_05769': 'outer petals are green in color,inner petals are pink in color',
#  'image_00940': 'the flower has smooth white petals with yellow on the inside',
#  'image_04231': 'purple white and yellow petals white petals with purple tips yellow petals with purple tips middle has purple stripes on the white and yellow petals',
#  'image_05307': 'the flower shown has several white petals and yellow stamen.',
#  'image_06683': 'the petals on this flower are yellow with no visible stamen.',
#  'image_05997': 'the petals of this flower are white with a long stigma',
#  'image_06464': 'this flower has dark green pistil and small blue petals as its main features',
#  'image_02485': 'a single round petal, blue with five pointed purple stripes, narrows down into a white cone shape, in which there is a single white stamen.',
#  'image_01523': 'this flower is pink and white in color, with petals that are leaf like.',
#  'image_03237': 'the flower shown has a thin green pedicel with yellow pistil and petals',
#  'image_08033': 'this flower is pink and yellow in color, with petals that are spotted.',
#  'image_06456': 'this colorless flower has a lot of stigma and stamen.',
#  'image_04703': 'this is a purple flower with white on the petals and anther filaments.',
#  'image_01964': 'the flower has a single petal and its red in color with stalk the center.',
#  'image_07750': 'a long green pedicel comes out from a group of round yellow petals.',
#  'image_06206': 'the flower shown has small white petals and yellow pistil which are its main features',
#  'image_02791': 'the flower shown has red petals and red anthers as its main feature.',
#  'image_02053': 'large heart shaped red petal with a long slender yellow style',
#  'image_02065': 'this flower has petals that are pink with white and yellow style',
#  'image_00262': 'this flower has a wide yellow center surrounded by several layers of pointed, upturned petals.',
#  'image_02506': 'this flower small flat petals in either deep purple or white with purple markings.',
#  'image_05655': 'this flower has a few bright pink petals that turn more white in the center.',
#  'image_04982': 'the flower petals are closely parked and are yellow in color',
#  'image_06156': 'the star shaped white flower has petals that are fused near the sepal and flaring out as separate in the outer region',
#  'image_06304': 'the flower has many petals that are yellow with yellow stamen.',
#  'image_04964': 'leaves are green,the petals are overlap and are yellow in color',
#  'image_05197': 'bright yellow petals with a faint shine and slight creases surround a bundle of squat stamens in several layers.',
#  'image_01791': 'this flower is white and red in color, and has a large style that is white.',
#  'image_00847': 'this flower has a a lot of white petals with a yellow center without any stamen',
#  'image_05820': 'this flower has many white and purple blossoms growing upward off a base of white petals with purple accents.',
#  'image_07164': 'the flower with yellow petals and brown spots has long and thin stamen',
#  'image_01017': 'this flower is red and white in color, with petals that are circle shaped.',
#  'image_00921': 'the petals of this flower are white and yellow with a short stigma',
#  'image_07693': 'this flower contains round yet sparse petals that are pink, the stigma is also pink and spotted yellow.',
#  'image_00167': 'this flower has petals that are purple with purple stamen',
#  'image_07150': 'this flower has petals that are purple with yellow stamen',
#  'image_07543': 'this flower has small white petals and a few white anther in the center',
#  'image_01161': 'this flower has petals that are white with many layers',
#  'image_03447': 'the greenish white flower is inverted and has petals that are soft, smooth and separately arranged around the supporting green pedicel',
#  'image_00176': 'this flower has yellow pistil and purple petals as its main features',
#  'image_04697': 'this flower is purple in color, with petals that are wrapped around each other.',
#  'image_07034': 'this flower is lotus shaped with white pedals and poach like receptacles.',
#  'image_07833': 'this flower has long red petals and a red stigma in the center of it',
#  'image_06021': 'the purple flower has different shapes of petals and has no stamens.',
#  'image_01869': 'this flower is star shaped with petals and its stamen is yellowish',
#  'image_02567': 'this flower has petals that are white with yellow stamen',
#  'image_05553': 'this flower is pink and purple in color, with petals that are oval shaped.',
#  'image_05980': 'smooth white petals that form a star shape with white and yellow stamen surrounding the light green stigma.',
#  'image_01336': 'this flower with pink petals having dark pink shades in center with green color sepal and pedicel.',
#  'image_05637': 'this is a flower with ruffled petals that are pink and white.',
#  'image_07254': 'the petals of this flower are pink with a long stigma',
#  'image_00891': 'this flower has five smooth white petals with slightly pointed edges and yellow centers.',
#  'image_03097': 'the flower has many overlapping petals that are bright yellow.',
#  'image_01769': 'this flower has petals that are red with a yellow stigma',
#  'image_08036': 'this flower features large oval orange and red flocked petals surrounding prominent orange stamens.',
#  'image_03123': 'this flower has thick white petals as its main feature.',
#  'image_08176': 'the flower has light pink petals that are arranged in a disc manner around the yellow stamen',
#  'image_01874': 'the flower is formed by alternating pink petals that curve upward to form a bowl.',
#  'image_05435': 'this flower is yellow in color, with petals that are pointed.',
#  'image_07810': 'this flower has white anther and purple petals as its main features',
#  'image_04398': 'the flower is pink that has two layer of petals with bottom layer forming disc like shape and upper layer is bell shaped',
#  'image_04743': 'this flower has small purple petals and some white stamen in the middle',
#  'image_00429': 'the pedicel of this flower cannot be seen and the petals are pink.',
#  'image_00809': 'leaves are green,flower is white in color with some yellow patches',
#  'image_03675': 'this flower is white and yellow in color, with petals that are yellow near the ovule.',
#  'image_03321': 'this flower is yellow and purple in color, with petals that are skinny and pointed.',
#  'image_05162': 'a round flower with yellow petals and yellow stamen in the center.',
#  'image_01365': 'this large blossom has wide red petals which are slightly ruffled.',
#  'image_01028': 'the orange flower has oval petals with red and maroon stamen.',
#  'image_04893': 'this flower is white and pink in color, with petals that have pinks striped.',
#  'image_04217': 'this flower has petals that are purple with yellow and white patches with black lines',
#  'image_04657': 'this flower has five large, wide overlapping petals with rounded edges.',
#  'image_07686': 'the flower is bell shaped and has petals that are red with single layer and a enclosing the stamen',
#  'image_06251': 'this flower has vertical purple stamen surrounding small shiny yellow petals.',
#  'image_04235': 'the petals on this flower are purple, white, yellow and brown.',
#  'image_02397': 'this flower has white stamen and a pink center surrounded by delicately ruffled white petals.',
#  'image_01347': 'this flower features a frame of delicate red petals surrounding a yellow center.',
#  'image_07220': 'this flower has petals that are white with green pedicel.',
#  'image_08179': 'pedicel is green in color,petals are white in cplor with yellow anthers',
#  'image_05999': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_03420': 'this drooping flower has long petals in shades of mottled plum.',
#  'image_03559': 'the star shaped pink flower has petals that are soft, smooth and has stamens sticking out from the centre',
#  'image_02814': 'the petals of the flower are bright red while there are many yellow stamen and the middle is dark red.',
#  'image_01092': 'this flower is red and yellow in color, with petals that are yellow at the edges.',
#  'image_06010': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_03783': 'several long, thin, grasslike pinkish purple petals with long thin white stamen with purple anthers.',
#  'image_07146': 'this flower is blue and black in color, with petals that are wavy and rounded.',
#  'image_00359': 'many smooth spoon shaped white petals create an open ball shaped flower with clusters of yellow stamen in the center.',
#  'image_07817': 'the wrinkled and fragile petals are a calming lavender gathering to the center.',
#  'image_03041': 'this flower has thin red petals as its main feature.',
#  'image_01342': 'this flower has a single large red petal around it with thin streaks of dark red heading in five directions.',
#  'image_04244': 'the flower has petals that are red with white edges and red filaments.',
#  'image_01366': 'this flower is red in color, with petals that are wavy and ruffled.',
#  'image_03076': 'sepals are green in color,petals are red in color and are needle shaped',
#  'image_03243': 'the petals of this flower are yellow with a long stigma',
#  'image_02647': 'this flower is composed of small red rounded petals tightly clustered together.',
#  'image_02609': 'five rounded petals surrounded by five offset maroon pointed petals. multiple yellow stamen come out from the center of the flower.',
#  'image_04083': 'this flower has many long, lavender stamen coming from the center of many layers of greenish brown, thick petals.',
#  'image_01170': 'the flower petals are alternately arranged ,they are pink in color',
#  'image_06160': 'a bulb beige stigma accompanied by triangular white shaped smooth petals.',
#  'image_00152': 'this is a flower with white petals and stringy purple and white anthers.',
#  'image_07273': 'this flower is purple and yellow in color, with petals that are different shapes.',
#  'image_00713': 'the flower has a large bright orange petal with pink anther',
#  'image_00353': 'this flower has petals that are pink with yellow stamen',
#  'image_02422': 'these pale pink flowers are somewhat tube shaped with long purple stamen in the middle.',
#  'image_00047': 'this flower has green anther and a purple stigma on top of white and purple petals.',
#  'image_07680': 'this flower has white curved petals with yellow anther and a green pedicel.',
#  'image_00693': 'the petals on this flower are yellow with red blotches.',
#  'image_00078': 'this flower has star shaped purple petals as its main feature.',
#  'image_03136': 'green pedicel and sepal supporting sparse pink, yellow and white petals.',
#  'image_03599': 'this flower has a very wavy texture and it is pink.',
#  'image_06725': 'this flower has long white petals that have purple dots on it, and a large green stigma on it',
#  'image_03872': 'the flower has wither petals with dry end at the tips.',
#  'image_02000': 'one large love shaped petal with a prominent pistil',
#  'image_01643': 'this star shaped flower has white petals that have a lightish purple in the middle with a yellow stamen',
#  'image_04926': 'this flower has petals that are white with yellow style',
#  'image_01200': 'this flower has green pedicel and bright pink petals as its main features',
#  'image_07364': 'this flower has white and magenta petals that are covered in brown spots.',
#  'image_03358': 'this flower has petals that are yellow and are pointy',
#  'image_07570': 'the petals on this flower are white with white stigma.',
#  'image_06932': 'the flower has petals that are pink with yellow filament.',
#  'image_04298': 'the beautiful petals are white with pink dots on the petals .',
#  'image_06709': 'this flower has mottled pink and brown petals, and fuzzy green pedicels.',
#  'image_02957': 'the flower has peach and yellow petals shaped like little shells',
#  'image_04896': 'this flower has red and white petals along with a green pedicel.',
#  'image_01907': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_05506': 'this flower has long pink petals and no visible stigma in the center',
#  'image_04557': 'the petals of this flower are yellow with a short stigma',
#  'image_08044': 'a tan pedaled flower with a black dots, and a green stems.',
#  'image_07205': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_02692': 'the reddish orange flower has petals that are soft, smooth, thin and separately arranged around stamens in disc like manner',
#  'image_00909': 'this flower has petals that are pale blue with centers of yellow and pink.',
#  'image_03031': 'this flower has many bright purple petals that appear to have barbs or come to a sharp point at their ends.',
#  'image_00775': 'the flower has large deep yellow petals, with some red veins near the base of the petal. it has the same deep yellow color on the stamen and pistil',
#  'image_04502': 'this flower has red and yellow petals with a core of low-lying yellow stamen.',
#  'image_05323': 'the petals on this flower are white with yellow stamen.',
#  'image_01794': 'this veiny orange flower has dark orang in the center and orange anther.',
#  'image_00730': 'this flower is orange in color, with petals that are ruffled and rounded.',
#  'image_02515': 'light purple flayed petals with a dark purple center revealing a light pink and white pistil.',
#  'image_03314': 'this flower has petals that are pointed and orange with white centers.',
#  'image_00605': 'the flower shown has yellow petals as well as yellow stamen',
#  'image_00935': 'this flower has thick white and yellow petals as its main feature.',
#  'image_00792': 'this flower has petals that are yellow with white edges.',
#  'image_03754': 'this flower has petals that are pink and very thin',
#  'image_05617': 'this flower has petals that are blue with white patches',
#  'image_01276': 'a creme orange flower with the pedals wrapping around it.',
#  'image_02748': 'this flower has dark red petals with some small white markings.',
#  'image_06003': 'this flower has white petals and yellow pisitl as its main features',
#  'image_05176': 'the flower shown has orange and yellow petals with yellow stamen in the center',
#  'image_05129': 'the petals on this flower are purple, green, white, and yellow.',
#  'image_01209': 'this flower is pink and white in color, with petals that are closely wrapped around the ovule.',
#  'image_04734': 'a purple and white veiny flower with rounded petals and a green pedicel.',
#  'image_01130': 'these flowers have yellow and dark orange petals with yellow tipped stamen.',
#  'image_00378': 'this flower has a yellow center surrounded by several upturned layers of white petals with pointed tips.',
#  'image_06660': 'this flower has large yellow petals and no visible stigma',
#  'image_07826': 'the violet petals of this flower are in the process of wilting.',
#  'image_07784': 'this flower has ruffled, light purple petals and pale yellow anthers.',
#  'image_04535': 'this flower has petals that are yellow with red lines',
#  'image_06386': 'the pretty flower has yellow petals the are long and curve down.',
# ...
#  'image_02158': 'this flower is white in color, with petals that are horn shaped.',
#  'image_00419': 'this flower has petals that are purple with yellow stamen',
#  'image_06260': 'this flower is yellow and red in color, with petals that are oddly shaped.',
#  'image_06289': 'this flower has petals that are red and yellow and tiny',
#  'image_07775': 'this flower is white in color, with petals that are shaped like a funnel.',
#  'image_01119': 'this flower has petals that are orange with white stamen',
#  'image_02964': 'this flesh colored flower has oval shaped pedals thats it amongst each other with green variegated leaves and anther.',
#  'image_08058': 'flower has petals that are red with a white stripe.',
#  'image_00199': 'the flower has light green petals and spiky purple petals as well.',
#  'image_05151': 'this flower has several yellow stamen surrounded by numerous rows of long, rounded yellow petals.',
#  'image_04125': 'this flower has a very large cluster of purple stamen surrounded by sharp thick green petals',
#  'image_02576': 'this flower looks like 2 and 1 it has 3 colors on the titles yellow purple and in white',
#  'image_05982': 'this flower has short yellow stamen surrounded by several large rounded white petals.',
#  'image_01005': 'this flower has several smooth rounded petals in an orange and red shade.',
#  'image_02720': 'the petals of the flower are red in color and fold inward around the organs.',
#  'image_01460': 'this flower has large white petals and no visible outer stamen in it',
#  'image_07085': 'this flower has white pedicel and purple petals as its main features',
#  'image_00499': 'this flower is pink in color, with petals that are rounded on the ends.',
#  'image_05954': 'the flower has a petals color purple with white stripes on it.',
#  'image_05095': 'this flower has large purple petals and a yellow stigma in the center',
#  'image_07187': 'this flower has a large orange petal and green stamen with brown anthers in the center',
#  'image_03688': 'the flower has petals that are orange with yellow edges.',
#  'image_05649': 'these flowers have thin and orange petals that grow vertically from each other.',
#  'image_00864': 'this flower has petals that are white with yellow centers.',
#  'image_00010': 'the petals on this flower are white with an elaborate pistil.',
#  'image_01207': 'this flower has petals that are pink with many layers',
#  'image_08069': 'petals are rounded in shape ,they are white and pink in color',
#  'image_01847': 'this is a flower with pink petals that have darker pink tips.',
#  'image_03207': 'this bright yellow petals grow upwards away from the short long thin stamen.',
#  'image_07319': 'these flowers are shaped like yellow cones with red speckles on the inside.',
#  'image_06884': 'a big bunch of several tiny orange flowers growing radially out from a thick central stem.',
#  'image_01096': 'the petals of this flower are yellow with a short stigma',
#  'image_06441': 'a 5-petaled, star-shaped flower with bluish purple color which highlights the dark burgundy stigmas and stamens in the center.',
#  'image_07224': 'these bland, white petaled flowers have a yellow pistil and flower center.',
#  'image_01433': "this flower has a white colored set of petals with small veins in them that's green in color.",
#  'image_03716': 'this flower looks flat and has a ring of six overlapping round white petals with yellow centers.',
#  'image_03655': 'this flower is yellow in color, with petals that have darker veins.',
#  'image_02418': 'this flower has petals that are orange with orange stamen',
#  'image_00174': 'this pale white flower has 10 petals with striking white and purple upright inner petals surrounding the pistil.',
#  'image_04097': 'this flower is purple in color, and has petals that are very skinny.',
#  'image_07961': 'the flower is trumpet shaped with orange-red petals that end rounded with some green and white stamen poking out of the trumpet.',
#  'image_02403': 'this flower has petals that are white with purple edges',
#  'image_06526': 'pedicel is green in color,petals are red in color',
#  'image_05974': 'this flower has bright white broad oval shaped petals with light yellow stamen in the middle.',
#  'image_03820': 'peals are pink in color,with larger anthers that are drak pink',
#  'image_08148': 'the flower has teardropped petals that are white are sparse.',
#  'image_07429': 'the flower shown has purple bell shaped petals which are its main feature',
#  'image_04802': 'this flower has five slightly pointed petals which are pale pink with striking fuchsia edging all along the borders.',
#  'image_00371': 'the flower has petals that are white with yellow filaments.',
#  'image_01418': 'this flower has petals that are white with yellow lines',
#  'image_01107': 'the petals of the flower are yellow while the anthers are white and the pistil is red.',
#  'image_05022': 'the petals on this flower are orange and thin with visible pistils',
#  'image_00404': 'pedicel are green in color,sepals are green and the petals are light puple',
#  'image_07256': 'this is a small flower with white petals and red stamen.',
#  'image_00077': 'this flower has petals that are yellow with purple stamen',
#  'image_02432': 'this flower is white and pink in color, with petals that are pink near the edges.',
#  'image_08019': 'this flower has large orange with red spotted petals that have their own stems.',
#  'image_02589': 'this white flower has an outer ring of pointed petals surrounding a circle or rounded petals that have dips.',
#  'image_07032': 'this flower has petals that are dark pink and overlapping.',
#  'image_07794': 'this flower has petals that are light pink with pink stamen.',
#  'image_05404': 'this flower is yellow and brown in color, with petals that are oval shaped.',
#  'image_01081': 'the purple buds bloom into rounded yellow petals, one on either side of the green-white stamens.',
#  'image_05265': 'this flower has a purple leaves in a vase like structure with dark green insides on petals and white anthers on purple style.',
#  'image_03008': 'this flower has petals that are orange with yellow shading',
#  'image_06188': 'this flower has petals that are purple with white stamen',
#  'image_00282': 'this flower has several overlapping layers of which pointed petals in various shades of pink.',
#  'image_05154': 'this flower is orange and yellow in color, with petals that are layered and oval shaped.',
#  'image_02804': 'this flower is red in color, with petals that are oval shaped.',
#  'image_06830': 'sepals are green in color,leaves are green in color and the petals are red in color',
#  'image_01655': 'this is a large purple flower with a prominent yellow stigma.',
#  'image_06967': 'the petals of this flower are petals with short little stamen',
#  'image_01995': 'this flower has long red petals and a long yellow stigma in the center',
#  'image_00335': 'the white petals are overlapping each other and the stamen is yellow in color.',
#  'image_01008': "this smaller flower of four orange petals with tiny red stripes has a small cluster of yellow stamen at it's core.",
#  'image_00606': 'the petals on this flower are orange with orange stamen.',
#  'image_06071': 'this flower is pink and green in color, with petals that are pointed.',
#  'image_08043': 'this flower has petals that are red and yellow with spots',
#  'image_07283': 'a flower with purple petals and yellow anther filaments and pistils.',
#  'image_03970': 'this flower has bright pink petals that are wide and flat.',
#  'image_05659': 'this flower has large white petals that seem to go around the rest of the flower.',
#  'image_05430': 'the flower is big and has petals that are soft, smooth and separately arranged around bunch of stamen',
#  'image_03607': 'this flower contains a condensed pink/purple petal arranged in a ring structure, followed by red/purple pistils in the centerpiece.',
#  'image_00354': 'this flower has petals that are pink with yellow stamen',
#  'image_06717': 'this flower has petals that are purple with a big stigma',
#  'image_08112': 'this flower is purple and pink in color, with petals that are oddly shaped.',
#  'image_07823': 'this flower is white and pink in color, with petals that are curled backwards.',
#  'image_07476': 'this flower has petals that are purple with yellow flower steman',
#  'image_05070': 'this flower has petals that are orange with yellow steman',
#  'image_07557': 'this flower has petals that are red with flowery stigma',
#  'image_03744': 'the flower shown has purple petals with a purple pedicel',
#  'image_02852': 'the petals of the flower are red in color with a center made of orange anthers.',
#  'image_03403': 'pedicel are brown in color,petals are maroon and black in color',
#  'image_02210': 'this bright red flower has petals that layer and grow to a point.',
#  'image_05826': 'this flower has long white petals and a group of white stamen with white anthers on it',
#  'image_04400': 'the flower has curled, jagged purple petals that turn yellow towards the center.',
#  'image_05833': 'this unique flower has a dense inside filled with stamen and purple petals.',
#  'image_06442': 'this flower has petals that are blue with green stamen',
#  'image_04972': 'this flower has little yellow petals and green pedicel as its main features',
#  'image_05290': 'this is a large blossom with white petals and many small yellow stamen surrounding a yellow pistil.',
#  'image_01415': 'this bright white flower has white petals that are a pale yellow color toward the stigma.',
#  'image_07624': 'the petals of this flower are pink with a short stigma',
#  'image_03137': 'these flowers grow in clusters upwards surrounding a single stalk, with petals that are yellow and pale pink.',
#  'image_02390': 'dark purple pedals with white stripes and long green leaves light purple middle',
#  'image_04159': 'this flower has large purple petals with yellow centers and two visible white anthers',
#  'image_07172': 'the stamen are white in color and the anthers are large and maroon in color',
#  'image_02088': 'the flower shown has thick white petals as its main feature.',
#  'image_03048': 'this flower has petals that are pink and very thin',
#  'image_01953': 'this flower is pink in color, with petals that are oval shaped.',
#  'image_00272': 'a white flower with petals that are soft, smooth, separated and surround the stamen in many layers',
#  'image_06558': 'this flower is round and flat, a sunshine yellow, and the petals are numerous and very long and thin.',
#  'image_01614': 'this flower has large purple petals and a long white stamen on it',
#  'image_07065': 'this flower has white petals and yellow pistil as its main features',
#  'image_02420': 'the flower shown has a green pedicel with yellow petals',
#  'image_06407': 'this flower is purple in color, with petals that have dark veins.',
#  'image_07877': 'this flower is white and red in color, with petals that are pointed at the tips.',
#  'image_06890': 'this is a flower with pink ruffled petals with white tips.',
#  'image_02930': 'this flower features layers of purple tinged white petals relaxing at the perimeter.',
#  'image_03003': 'this flower is yellow and peach in color, with petals that are oval shaped.',
#  'image_06530': 'this flower has a numerous amount of thin bright yellow petals.',
#  'image_08051': 'the red petals are shaped like an acorn on this flower',
#  'image_06352': 'the flower shown has a yellow petal with a green pedicel',
#  'image_07902': 'the flower has red petals with yellow tips and a green pedicel',
#  'image_02583': 'the petals on this flower are white with yellow stamen.',
#  'image_01057': 'these flower has no more than five red petals and a few white stamens.',
#  'image_04415': 'the large petaled orange and yellow flowers have stamen that are hidden between the center petals.',
#  'image_05419': 'a large dark black ovary surrounded by many long yellow petals',
#  'image_05808': 'the petals are white and no stamen and pistil can be seen on the flower.',
#  'image_05686': 'this flower has vibrant yellow petals in two layers, one that grows up and away from the yellow pistil.',
#  'image_02540': 'this is a flower with thin, wide pink petals and a white pollen tube.',
#  'image_06162': 'this flower has petals that are purple with dark lines',
#  'image_00880': 'a flower that has white petals and a yellow center',
#  'image_03955': 'this flower has petals that are purple with dark lines',
#  'image_06797': 'these red and yellow flower petals and flowing, pale yellow sepals.',
#  'image_01330': 'this flower is pink and white in color, with petals that are connected.',
#  'image_05191': 'the flower has dense yellow petals that are long and thin.',
#  'image_04564': 'white and purple specs petal green middle greenleaf',
#  'image_00810': 'this double colored flower has a whirl of overlapping petals with white and yellow',
#  'image_06385': 'the flower shown has three large yellow petals, with small black lines.',
#  'image_02398': 'this flower has petals that are orange with shades of yellow',
#  'image_02657': 'the petals on this flower are red with red stamen.',
#  'image_00418': 'these flowers with many offset petals in pink and yellow shades sit on the water surrounded by rounded green leaves.',
#  'image_06826': 'this flower has stacked pink petals as its main features',
#  'image_06703': 'a small purple spotted flower with petals that curl downward and have dropping purple anther.',
#  'image_06043': 'the petals look like pink a pink leaf that hangs upside down',
#  'image_06493': 'the bowl shaped red flower has petals that are soft, smooth, thin and arranged separately overlapping each other',
#  'image_05275': 'the flower has light blue petals and the stamen is a greenish colour',
#  'image_04278': 'the flower has alternatly arranged red colored petals tha are rounded in shape with large anthers',
#  'image_01686': 'the eight petals of this blossom resemble leaves but are purple with white veins, the center has white stamen with purple ends.',
#  'image_04590': 'this flower is pink in color, with petals that are curled downward.',
#  'image_07398': 'this flower has bright purple round petals with white and red spots on the inside.',
#  'image_06022': 'this flower is pink and white in color, with petals that are pointed on the ends.',
#  'image_07669': 'this flower has overlapping pale pink petals and many small yellow stamen.',
#  'image_04996': 'the petals of the flower are yellow and have curled edges.',
#  'image_07269': 'the five lavender petals give this blossom a star shape, with a yellow center featuring long yellow filaments.',
#  'image_02519': "this purple flower has a white center and petals that touch to form a circle, there are red lines that go down the petal's center toward the outer edge of the flower.",
#  'image_00083': 'this flower has large green-yellow stamens and two types of purple petals.',
#  'image_06510': 'this flower has large rounded light red petals with a green pedicel.',
#  'image_07798': 'the flower has a soft purple petal with a green pedicel',
#  'image_04627': 'this flower is bright yellow with many yellow stamen.',
#  'image_06503': 'the petals are bright red and rounded with a deep blue color in the center, the stigma is light green.',
#  'image_04048': 'this flower is yellow in color, with petals that are very skinny and layered.',
#  'image_00106': 'this flower is purple and white in color, with petals that are oval shaped.',
#  'image_04007': 'a vivid yellow flower with spiked looking petals and a darker yellow center.',
#  'image_05035': 'a flower that has dark orange petals and lighter orange filaments in the center',
#  'image_00946': 'this flower is white and yellow in color, with petals that are oval shaped.',
#  'image_00308': 'this flower has pink petals, white petals, as well as yellow anther and filament.',
#  'image_00626': 'this flower has petals that are yellow and orange with yellow stamen',
#  'image_07723': 'this flower has petals that are orange and yellow',
#  'image_04602': 'this flower is white and green in color, with petals that are curled inward.',
#  ...}

# %% [markdown]
# ### Caption Encoder
# Sử dụng mô hình BERT để biểu diễn mỗi câu mô tả thành 1 vector có 768 chiều

# %%
import torch
import numpy as np
from sentence_transformers import SentenceTransformer

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
bert_model = SentenceTransformer("all-mpnet-base-v2").to(device)

def encode_captions(captions):
    encoded_captions = {}
    for image_name in captions.keys():
        caption = captions[image_name]
        encoded_captions[image_name] = {
            "embed": torch.tensor(bert_model.encode(caption)),
            "text": caption
        }
    return encoded_captions

encoded_captions = encode_captions(captions)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Preprocessing

# %%
from PIL import Image
from torch.utils.data import Dataset

class FlowerDataset(Dataset):
    def __init__(self, img_dir, captions, transform=None):
        self.img_dir = img_dir
        self.transform = transform
        # Load captions
        self.captions = captions
        self.img_names = list(self.captions.keys())

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img_name = self.img_names[idx]
        img_path = os.path.join(self.img_dir, img_name+".jpg")
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        encoded_caption = self.captions[img_name]["embed"]
        caption = self.captions[img_name]["text"]
        return {
            "image": image,
            "embed_caption": encoded_caption,
            "text": caption
        }

# %%
import torchvision.transforms as transforms

from torch.utils.data import DataLoader

IMG_SIZE = 128

transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

ds = FlowerDataset(
    img_dir="./content/cvpr2016_flowers/images",
    captions=encoded_captions,
    transform=transform
)

BATCH_SIZE = 256
dataloader = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# ### Model

# %% [markdown]
# #### Generator

# %%
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self, noise_size=100, feature_size=128, num_channels=3, embedding_dim=768, reduce_dim_size=256):
        super().__init__()

        self.text_encoder = nn.Sequential(
            nn.Linear(embedding_dim, reduce_dim_size),
            nn.BatchNorm1d(num_features=reduce_dim_size),
            nn.LeakyReLU(negative_slope=0.2, inplace=True)
        )

        self.up_sampling = nn.Sequential(
            # (100 + 256, 1, 1) -> (1024, 4, 4)
            nn.ConvTranspose2d(noise_size + reduce_dim_size, feature_size * 8,
                               kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(feature_size*8),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),

            # (1024, 4, 4) -> (512, 8, 8)
            nn.ConvTranspose2d(feature_size * 8, feature_size * 4,
                               kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(feature_size*4),
            nn.ReLU(inplace=True),

            # (512, 8, 8) -> (256, 16, 16)
            nn.ConvTranspose2d(feature_size * 4, feature_size * 2,
                               kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(feature_size*2),
            nn.ReLU(inplace=True),

            # (256, 16, 16) -> (128, 32, 32)
            nn.ConvTranspose2d(feature_size * 2, feature_size,
                               kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(feature_size),
            nn.ReLU(inplace=True),

            # (128, 32, 32)-> (128, 64, 64)
            nn.ConvTranspose2d(feature_size, feature_size,
                               kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(feature_size),
            nn.ReLU(inplace=True),

            # (128, 64, 64) -> (3, 128, 128)
            nn.ConvTranspose2d(feature_size, num_channels,
                               kernel_size=4, stride=2, padding=1, bias=False),
            nn.Tanh()
        )

    def forward(self, noise, text_embedding):
        text_encode = self.text_encoder(text_embedding)
        x = torch.cat((noise, text_encode), dim=1)
        x = x.unsqueeze(2).unsqueeze(2)
        output = self.up_sampling(x)
        return output

# %% [markdown]
# #### Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_channels=3, feature_size=128, embedding_size=768, reduced_dim_size=256):
        super().__init__()
        self.image_encoder = nn.Sequential(
            # (3, 128, 128) -> (128, 64, 64)
            nn.Conv2d(in_channels, feature_size, 4, 2, 1, bias=False),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),

            # (128, 64, 64) -> (128, 32, 32)
            nn.Conv2d(feature_size, feature_size, 4, 2, 1, bias=False),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),

            # (128, 32, 32) -> (256, 16, 16)
            nn.Conv2d(feature_size, feature_size * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(feature_size * 2),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),

            # (256, 16, 16) -> (512, 8, 8)
            nn.Conv2d(feature_size * 2, feature_size * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(feature_size * 4),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),

            # (512, 8, 8) -> (1024, 4, 4)
            nn.Conv2d(feature_size * 4, feature_size * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(feature_size * 8),
            nn.LeakyReLU(negative_slope=0.2, inplace=True),
        )

        self.text_encoder = nn.Sequential(
            nn.Linear(in_features=embedding_size, out_features=reduced_dim_size),
            nn.BatchNorm1d(num_features=reduced_dim_size),
            nn.LeakyReLU(negative_slope=0.2, inplace=True)
        )
        self.final_block = nn.Sequential(
            nn.Conv2d(feature_size * 8 + reduced_dim_size, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input_img, text_embeddings):
        image_encoded = self.image_encoder(input_img)
        text_encoded = self.text_encoder(text_embeddings)
        replicated_text = text_encoded.repeat(4, 4, 1, 1).permute(2, 3, 0, 1)
        concat_layer = torch.concat((image_encoded, replicated_text), 1)
        x = self.final_block(concat_layer)
        return x.view(-1, 1), image_encoded

# %% [markdown]
# ### Training

# %%
import matplotlib.pyplot as plt
import torchvision

def show_grid(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

show_grid(torchvision.utils.make_grid(ds[0]["image"], normalize=True))

plt_o_text_embeddings = ds[0]['embed_caption'].view(1, -1)
caption = ds[0]['text']

def plot_output(generator):
    plt.clf()
    with torch.no_grad():
        generator.eval()
        noise = torch.rand((1, 100))
        test_images = generator(noise.to(device), plt_o_text_embeddings.to(device))
        generator.train()
        print(test_images.shape)
        grid = torchvision.utils.make_grid(test_images.cpu(), normalize=True)
        show_grid(grid)

# %%
import torch.optim as optim

generator = Generator(noise_size=100,
                      feature_size=128,
                      num_channels=3,
                      embedding_dim=768,
                      reduce_dim_size=256).to(device)

discriminator = Discriminator(in_channels=3,
                             feature_size=128,
                             embedding_size=768,
                             reduced_dim_size=256).to(device)
optimizer_G = optim.Adam(generator.parameters(), lr=2e-4, betas=(0.5, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=2e-4, betas=(0.5, 0.999))

bce_loss = nn.BCELoss()
l2_loss = nn.MSELoss()
l1_loss = nn.L1Loss()

# %%
import time

epochs = 500

for epoch in range(epochs):
    g_losses, d_losses = [], []
    epoch_time = time.time()

    for batch in dataloader:
        images = batch['image'].to(device)
        embed_captions = batch['embed_caption'].to(device)

        # create real/fake labels
        real_labels = torch.ones(images.size(0), 1, device=device)
        fake_labels = torch.zeros(images.size(0), 1, device=device)

        #### train Generator
        optimizer_G.zero_grad()
        # create noise
        noise = torch.randn(size=(images.size(0), 100), device=device)
        gen_img = generator(noise, embed_captions)

        outputs, fake_features = discriminator(gen_img, embed_captions)
        _, real_features = discriminator(images, embed_captions)

        # compute loss
        g_loss = bce_loss(outputs, real_labels)
        g_loss.backward()
        optimizer_G.step()
        g_losses.append(g_loss.item())


        #### train discriminator
        optimizer_D.zero_grad()
        # create noise
        noise = torch.randn(size=(images.size(0), 100), device=device)
        fake_images = generator(noise, embed_captions)

        # compute real loss
        outputs_real, _ = discriminator(images, embed_captions)
        real_loss = bce_loss(outputs_real, real_labels)

        # compute fake loss
        outputs_fake, _ = discriminator(fake_images.detach(), embed_captions)
        fake_loss = bce_loss(outputs_fake, fake_labels)

        # compute_loss
        d_loss = real_loss + fake_loss
        d_loss.backward()
        optimizer_D.step()
        d_losses.append(d_loss.item())

    avg_d_loss = sum(d_losses)/len(d_losses)
    avg_g_loss = sum(g_losses)/len(g_losses)
    if (epoch+1) % 10 == 0:
        plot_output(generator)
    print("Epoch [{}/{}] loss_D: {:.4f} loss_G: {:.4f} time: {:.2f}".format(epoch+1, epochs, avg_d_loss, avg_g_loss, time.time()- epoch_time))

# save model
model_save_path = "./save_model"
torch.save(generator.state_dict(), os.path.join(model_save_path, "generator.pth"))
torch.save(discriminator.state_dict(), os.path.join(model_save_path, "discriminator.pth"))
# Out:
# Epoch [1/500] loss_D: 1.8854 loss_G: 6.5486 time: 117.74
# Epoch [2/500] loss_D: 0.6776 loss_G: 3.0548 time: 117.77
# Epoch [3/500] loss_D: 1.2860 loss_G: 2.7634 time: 118.10
# Epoch [4/500] loss_D: 1.1847 loss_G: 2.4030 time: 118.10
# Epoch [5/500] loss_D: 1.0284 loss_G: 2.4281 time: 118.60
# Epoch [6/500] loss_D: 1.2095 loss_G: 2.7176 time: 118.55
# Epoch [7/500] loss_D: 1.1545 loss_G: 2.5585 time: 118.38
# Epoch [8/500] loss_D: 1.0073 loss_G: 2.9824 time: 118.71
# Epoch [9/500] loss_D: 1.1526 loss_G: 2.4087 time: 118.39
# torch.Size([1, 3, 128, 128])
# Epoch [11/500] loss_D: 1.2209 loss_G: 3.0113 time: 118.72
# Epoch [12/500] loss_D: 1.0932 loss_G: 2.4019 time: 118.56
# Epoch [13/500] loss_D: 1.0823 loss_G: 2.6371 time: 118.46
# Epoch [14/500] loss_D: 1.1026 loss_G: 2.4666 time: 118.52
# Epoch [15/500] loss_D: 1.0978 loss_G: 2.8471 time: 118.61
# Epoch [16/500] loss_D: 0.9791 loss_G: 2.5683 time: 118.69
# Epoch [17/500] loss_D: 0.9657 loss_G: 2.6996 time: 119.27
# Epoch [18/500] loss_D: 1.0630 loss_G: 2.5557 time: 119.14
# Epoch [19/500] loss_D: 0.9685 loss_G: 2.6087 time: 118.66
# torch.Size([1, 3, 128, 128])
# Epoch [20/500] loss_D: 1.0632 loss_G: 2.3284 time: 119.19

# %% [markdown]
# ### Inference

# %%
generator.eval()
caption = "this pale pink flower has a large yellow and green pistil."
embed_caption = torch.tensor(bert_model.encode(caption))
noise = torch.randn(size=(1, 100))
text_embedding = embed_caption.unsqueeze(0)
with torch.no_grad():
    test_images = generator(noise.to(device), text_embedding.to(device))
    grid = torchvision.utils.make_grid(test_images.cpu(), normalize=True)
    show_grid(grid)
